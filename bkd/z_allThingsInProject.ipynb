# %% [markdown]
# Your project uses multiple layers of technologies — backend, frontend, AI/LLM, email services, and deployment-related tools.

# %% [markdown]
# 🟦 1. Backend Stack
# 🚀 Flask
# Main backend framework
# Handles routing (/), form submission (POST), rendering templates
# 📧 smtplib + email.mime
# Native Python email library for sending meeting invitation emails
# 🔐 python-dotenv
# Loads environment variables (API keys, credentials) from .env
#
# 🟩 2. Frontend Stack
# 🎨 TailwindCSS (CDN version)
# Used for UI styling
# Provides responsive components & utility classes
# 📄 Jinja2 Template Engine
# Renders HTML dynamically inside Flask
# Displays extracted meeting data, email status, etc.
# ⚡ JavaScript
# Used for:
# Button loading animation
# Preventing multiple submissions
# 💻 HTML5
# Structure of the UI
#
# 🟨 3. AI / LLM Stack
# 🤖 Azure OpenAI (GPT-4o-mini or configured deployment)
# Processes user input
# Extracts structured meeting details using LLM prompt
# Uses:
# AzureOpenAI client
# Chat completion endpoint
# 📦 openai Python SDK
# API wrapper for interacting with Azure OpenAI
#
# 🟥 4. Email & Scheduling Logic
# 📧 Gmail SMTP
# SMTP server: smtp.gmail.com:587
# Using app-password (nmoo cqtl cnnd nubr) (⚠️ security risk—should keep in secrets only!)
# 📨 Custom Email Utility (send_meeting_email)
# Builds HTML + plain text version of meeting email
# Sends meeting invite to each participant
# 🟫 5. Deployment / Environment
#
# (From your structure, these are implied)
# 🗂 Environment File
# .env contains:
# AZURE_OPENAI_API_KEY
# OPENAI_API_VERSION
# AZURE_OPENAI_ENDPOINT
# AZURE_OPENAI_DEPLOYMENT_NAME
# 🐍 Python 3.x
# Required to run Flask and OpenAI SDK

# %% [markdown]
# 🎯 Summary Table
#
# | Layer                      | Technologies                                      |
# | -------------------------- | ------------------------------------------------- |
# | **Backend**                | Flask, Python, smtplib, email.mime                |
# | **Frontend**               | HTML5, TailwindCSS, Jinja2, JavaScript            |
# | **AI / NLP**               | Azure OpenAI (GPT model), OpenAI SDK              |
# | **Email Service**          | Gmail SMTP, App Password                          |
# | **Environment Management** | python-dotenv                                     |
# | **Libraries Used**         | Flask, openai, python-dotenv, smtplib, email.mime |

# %% [markdown]
# hey listen
#
# --
# i have a project i want to add the Python flask backend with react frontend how can i do
# -
# i am share a file and the file structure with you please help me to do this
#
#
#
#
# yes my file structure is
# main file /
#   - forntend /
#   - Backend /
#
# this is 2 folder inside my main file or foder

# %% [markdown]
# backend/
#     - .env
#     - app.py
#     - schedulaer.py
#     - requirements.txt
#     - email_utils.py
#
# fornt-end /
#     - src
#     - .gitignore
#     - build_error.txt
#     - index.html
#     - packages-lock.json
#     - packages.config.js
#     - talwing.config.js
#     - vite.config.js
#
#
#
#
# -- ab mere src me bahut sara fiolder hai
#     - like
#     - component
#     - context
#     - pages
#
# but mere pages me kai sare files hai
#     - like
#     - activity.jsx
#     - auth.css
#     - calender.jsx
#     - AISceduler.jsx
#
#
# mujhe bas AISceduler.jsx ko mere flask backend se jodna hai kaise karu ye bas batana hai tumko tum chaho to mai tumko dono ka code de sakta hu
# - tumko samaj me aaya na

# %% [markdown]
# - Test
#     - Meeting link :     https://meet.google.com/znh-kowz-mnb
#     - Email's  :   rohanprasad065@gmail.com, rahulrao1849@gmail.com, shiwammaddheshiya@gmail.com, aliabdullahwork27@gmail.com
#     - Query : Schedule a meeting with Rohan, Shivam, Rahul, and Ali on Saturday at 3 PM. Meeting link :  https://meet.google.com/znh-kowz-mnb
